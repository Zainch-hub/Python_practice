# %% [markdown]
# # Python Variables and Data Types
#
# In this notebook, I practice creating variables, using different data types, and performing basic operations in Python.

# %% [markdown]
# # 1. print the name and age of a person

# %%
name = "Zain"
age = 20 
print("My name is",name , "and i am" , age , "years old")
# Out:
# My name is Zain and i am 20 years old

# %% [markdown]
# # 2.Take input from user and print values

# %%
name = input("Enter your name :")
age = input("Enter your age :")
print("Name :",name ,"\nAge :",age)
# Out:
# Enter your name : Zain
# Enter your age : 20
# Name : Zain
# Age : 20

# %% [markdown]
# # 3. Add two integers

# %%
a = 5 
b = 10
print("Sum :",a+b)
# Out:
# Sum : 15

# %% [markdown]
#  # 4. Print sum , multiplication , subtraction and division of those two numbers

# %%
a = 10
b = 20

sum = a+b 
subtraction = a-b
product = a*b
division = a/b

# %%
print("Sum :",sum,"\nSubtraction :",subtraction,"\nProduct :",product,"\nDivision :", division)
# Out:
# Sum : 30
# Subtraction : -10
# Product : 200
# Division : 0.5

# %% [markdown]
# # 5. Adding two Strings

# %%
a = " Zain "
b = " Asjad "
print(a+b)
# Out:
#  Zain  Asjad

# %%
print("Ali "+"son")
# Out:
# Ali son

# %% [markdown]
# # 6. Creating Variables

# %%
name = "Zain"
age = 20
height = 5.9
is_student = True

print(name)
print(age)
print(height)
print(is_student)
# Out:
# Zain
# 20
# 5.9
# True

# %% [markdown]
# # 7. Check Data Types

# %%
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # 8. Variable Reassignment

# %%
score = 80
print(score)

score = 95
print(score)
# Out:
# 80
# 95

# %% [markdown]
# #  9. Store the price of three products and Calculate: (Total price , Average price)

# %%
product_1 = 400
product_2 = 500
product_3 = 1000

total_price = product_1 + product_2 + product_3
average = total_price/3

print("Total price :",total_price)
print("Average price :",average)
# Out:
# Total price : 1900
# Average price : 633.3333333333334
