# %% [markdown]
# # Conditions and Branching
# -In condition set the condition is provided by doing comparison etc. and then further code is executed in the form of branches under every condition

# %% [markdown]
# # Condition Statements || Comparison operators

# %%
# Equal condition 
a = 4 
a == 5
# Out:
# False

# %%
a = "ABC"
a == "CDE"
# Out:
# False

# %%
# Greter than Condition
a = 7 
a > 6
# Out:
# True

# %%
# Less than operator
a = 7 
a < 6
# Out:
# False

# %%
# Not equal condition
a = 9
a != 12
# Out:
# True

# %%
a = "ABC"
a != "CDE"
# Out:
# True

# %% [markdown]
# # Branching

# %%
# Age example 

age = 19 

if age > 18:
    print( " You are an adult " )
else:
    print("You are a child ")
# Out:
#  You are an adult

# %%
# Player example 

player = " Lionel Messi " 
sport = "Soccor"
achievements = 8

if achievements == 8:
    print(f"The {player} meets the criteria, he plays {sport} and has {achievements}achievements")
else:
    print(f" The {player} doesnot meets the criteria")
# Out:
# The  Lionel Messi  meets the criteria, he plays Soccor and has 8achievements

# %%
# Another example executing else statement 

age = 18

if age > 18:
    print("Congradulations You can Enter ")
else:
    print("Go and see Meat Loaf")
print("Move On")
# Out:
# Go and see Meat Loaf
# Move On

# %%
# Elif statment example

age = 18

if age > 18:
    print("you can enter" )
elif age == 18:
    print("go see Pink Floyd")
else:
    print("go see Meat Loaf" )
    
print("move on")
# Out:
# go see Pink Floyd
# move on

# %% [markdown]
# # Logical Opeators

# %%
# Using AND Operator 
# Biometeric verification example 

id_card = "valid"
finger_prints = "matching"

if id_card =="valid" and finger_prints == "matching":
    print("Congratulations you can enter ")
else:
    print("Sorry! You can't enter ")
# Out:
# Congratulations you can enter

# %%
# Using OR Operator
# Album year example

album_year = 1990

if(album_year < 1980) or (album_year > 1989):
    print ("Album was not made in the 1980's")
else:
    print("The Album was made in the 1980's ")
# Out:
# Album was not made in the 1980's

# %%
# Player Example

player = "Roger Federer"
sport = "Tennis"
achievements = 20

if (sport == "Tennis") or ( achievements == 20 ):
    print(f"The {player} meets criteria and he plays {sport} and has {achievements} achievements ")
else:
    print(f"The {player} doesmot meets the citeria ")
# Out:
# The Roger Federer meets criteria and he plays Tennis and has 20 achievements

# %%
# Another Player Example

player = "Usian Bolt"
sport = "Athletics"
achievements = 8

if sport != "Soccor" and achievements < 10:
    print(f"The {player} meets the criteria, he plays {sport} and has {achievements} achievements")
else:
    print(f"The {player} doesnot meets the Criteria.")

# %%
# executing elif statement
# Age examole

age = 19
if age >= 21:
    print("You can enter the bar.")
elif age >= 18:
    print("You can watch a movie.")
else:
    print("Sorry, you cannot do either.")
# Out:
# You can watch a movie.
